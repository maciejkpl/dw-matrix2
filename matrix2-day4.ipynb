# %%
# !pip install eli5
# !pip install -U tables
# Out:
# ...
#      |████████████████████████████████| 112kB 2.8MB/s
# ...
#      |████████████████████████████████| 4.3MB 2.8MB/s
# ...
#   Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# ...

# %%
cd /content/drive/My Drive/Colab Notebooks/dw-matrix2
# Out:
# /content/drive/My Drive/Colab Notebooks/dw-matrix2

# %%
ls
# Out:
# data/               matrix2-day4.ipynb
# LICENSE             README.md
# matrix2-day2.ipynb  xgboost-0.81-py2.py3-none-manylinux1_x86_64.whl
# matrix2-day3.ipynb

# %%
import numpy as np
import pandas as pd

from sklearn.dummy import DummyRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

import xgboost as xgb

from sklearn.metrics import mean_absolute_error as mean_absolute_error
from sklearn.model_selection import cross_val_score, KFold

import eli5
from eli5.sklearn import PermutationImportance

pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# ...

# %%
df = pd.read_hdf("data/car.h5")
df.shape
# Out:
# (106494, 155)

# %%
org_df = df.copy()

# %%
df = org_df.copy()
bool_eur = df.price_currency == "EUR"
df.loc[bool_eur,'price_value'] *= 4.29 
df.loc[bool_eur,'price_currency'] = "PLN"

# %%
SUFFIX_CAT = "__cat"
for feat in df.columns:
    if isinstance(df[feat][0], list): continue
    
    factorized_values = df[feat].factorize(sort=True)[0]
    if SUFFIX_CAT in feat:
        df[feat] = factorized_values
    else:
        df[feat+SUFFIX_CAT] = factorized_values

# %%
cat_feats = [x for x in df.columns if "__cat" in x]
cat_feats = [x for x in cat_feats if "price" not in x]

# %%
X = df[cat_feats].values
y = df["price_value"].values

# %%
# model = DecisionTreeRegressor(max_depth=6)
# scores = -cross_val_score(model, X, y, cv=3, scoring="neg_mean_absolute_error", n_jobs=-1)
# np.mean(scores), np.std(scores)
# Out:
# (18771.103142348944, 327.5348392545289)

# %%
# m = DecisionTreeRegressor(max_depth=6)
# m.fit(X, y)
# imp = PermutationImportance(m, random_state=0).fit(X,y)

# %%
# eli = eli5.show_weights(imp, feature_names=cat_feats, top=30)
# eli
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2647
#
#                     &plusmn; 0.0051
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_napęd__cat
#             </td>
# ...

# %%
# df_fi = pd.DataFrame(zip(cat_feats, imp.feature_importances_), columns=["feat", "Perm_Importance"]).sort_values(by="Perm_Importance", ascending=False)
# important_features = list(df_fi["feat"][:20].values)
# important_features
# Out:
# ['param_napęd__cat',
#  'param_rok-produkcji__cat',
#  'param_faktura-vat__cat',
#  'param_stan__cat',
#  'param_moc__cat',
#  'param_marka-pojazdu__cat',
#  'param_skrzynia-biegów__cat',
#  'param_pojemność-skokowa__cat',
#  'feature_kamera-cofania__cat',
#  'feature_bluetooth__cat',
#  'param_kod-silnika__cat',
#  'feature_łopatki-zmiany-biegów__cat',
#  'feature_światła-led__cat',
#  'param_wersja__cat',
#  'seller_name__cat',
#  'feature_klimatyzacja-manualna__cat',
#  'param_model-pojazdu__cat',
#  'feature_immobilizer__cat',
#  'param_kolor__cat',
#  'feature_elektrycznie-ustawiane-fotele__cat']

# %%
# X = df[important_features].values
# y = df["price_value"].values

# for k in range(5,20):
#     model = DecisionTreeRegressor(max_depth=k)
#     scores = -cross_val_score(model, X, y, cv=3, scoring="neg_mean_absolute_error", n_jobs=-1)
#     print(k,": ",round(np.mean(scores)),"\t", round(np.std(scores)),"\t" ,round(np.mean(scores) + np.std(scores)))
# Out:
# 5 :  20021.0 	 126.0 	 20148.0
# 6 :  18804.0 	 309.0 	 19113.0
# 7 :  17844.0 	 180.0 	 18024.0
# 8 :  16975.0 	 211.0 	 17187.0
# 9 :  16170.0 	 356.0 	 16526.0
# 10 :  15479.0 	 173.0 	 15652.0
# 11 :  14903.0 	 252.0 	 15155.0
# 12 :  14488.0 	 232.0 	 14720.0
# 13 :  14282.0 	 260.0 	 14542.0
# 14 :  14048.0 	 237.0 	 14285.0
# 15 :  13933.0 	 229.0 	 14163.0
# 16 :  13859.0 	 133.0 	 13993.0
# 17 :  13824.0 	 183.0 	 14007.0
# 18 :  13867.0 	 211.0 	 14078.0
# 19 :  13906.0 	 182.0 	 14088.0

# %%
# # max_depth =17 seems best result, lets rerun eli5 estimations
# X = df[cat_feats].values
# y = df["price_value"].values
# m17 = DecisionTreeRegressor(max_depth=17)
# m17.fit(X, y)
# imp = PermutationImportance(m17, random_state=0).fit(X,y)
# eli = eli5.show_weights(imp, feature_names=cat_feats, top=50)
# eli
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4366
#
#                     &plusmn; 0.0446
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_rok-produkcji__cat
# ...

# %%
# df_fi = pd.DataFrame(zip(cat_feats, imp.feature_importances_), columns=["feat", "Perm_Importance"]).sort_values(by="Perm_Importance", ascending=False)
# important_features2 = list(df_fi["feat"][:30].values)

# %%
def run_model(model, feats):
    X = df[feats].values
    y = df["price_value"].values
    model = model
    scores = -cross_val_score(model, X, y, cv=3, scoring="neg_mean_absolute_error", n_jobs=-1)
    # return print("Depth", k, ": ", round(np.mean(scores)),"\t", round(np.std(scores)),"\t" ,round(np.mean(scores) + np.std(scores)))
    return print(round(np.mean(scores)),"\t", round(np.std(scores)),"\t" ,round(np.mean(scores) + np.std(scores)))

# %%
# for k in range(15,20):
#     model = DecisionTreeRegressor(max_depth=k)
#     feats = important_features
#     run_model(model, feats)
# Out:
# 15 :  13942.0 	 229.0 	 14171.0
# 16 :  13798.0 	 169.0 	 13967.0
# 17 :  13807.0 	 192.0 	 13999.0
# 18 :  13853.0 	 245.0 	 14098.0
# 19 :  13912.0 	 227.0 	 14139.0

# %%
rf = RandomForestRegressor(n_estimators=50, max_depth=15, n_jobs=-1)
run_model(rf, cat_feats)
# Out:
# 19 :  12073.0 	 210.0 	 12283.0

# %% [markdown]
# XG_BOOST

# %%
for k in range (9,12):

    xgb_params = {
        "max_depth":k,
        'n_estimators':100,
        "learning_rate":0.1,
        "seed":0,
        "tree_method":"gpu_hist"
    }

    run_model(xgb.XGBRegressor(**xgb_params), cat_feats)
# Out:
# Depth 9 :  9421.0 	 24.0 	 9445.0
# Depth 10 :  9316.0 	 49.0 	 9364.0
# Depth 11 :  9374.0 	 99.0 	 9474.0

# %%
X = df[cat_feats].values
y = df["price_value"].values

xgb_params = {
    "max_depth":10,
    'n_estimators':100,
    "learning_rate":0.1,
    "seed":0,
    "tree_method":"gpu_hist"
}

m = xgb.XGBRegressor(**xgb_params)
m.fit(X,y)

imp = PermutationImportance(m, random_state=0).fit(X,y)
eli = eli5.show_weights(imp, feature_names=cat_feats, top=50)
eli
# Out:
# [22:28:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2878
#
#                     &plusmn; 0.0131
#
#             </td>
# ...

# %%
df_fi = pd.DataFrame(zip(cat_feats, imp.feature_importances_), columns=["feat", "Perm_Importance"]).sort_values(by="Perm_Importance", ascending=False)
important_features_xgb = list(df_fi["feat"][:34].values)
important_features_xgb
# Out:
# ['param_rok-produkcji__cat',
#  'param_stan__cat',
#  'param_napęd__cat',
#  'param_skrzynia-biegów__cat',
#  'param_marka-pojazdu__cat',
#  'param_moc__cat',
#  'param_faktura-vat__cat',
#  'param_pojemność-skokowa__cat',
#  'feature_kamera-cofania__cat',
#  'param_typ__cat',
#  'param_wersja__cat',
#  'param_model-pojazdu__cat',
#  'param_kod-silnika__cat',
#  'feature_łopatki-zmiany-biegów__cat',
#  'seller_type__cat',
#  'feature_czujniki-parkowania-przednie__cat',
#  'feature_asystent-pasa-ruchu__cat',
#  'seller_name__cat',
#  'feature_wspomaganie-kierownicy__cat',
#  'param_rodzaj-paliwa__cat',
#  'seller_address__cat',
#  'feature_regulowane-zawieszenie__cat',
#  'created_at__cat',
#  'param_przebieg__cat',
#  'param_liczba-miejsc__cat',
#  'feature_światła-led__cat',
#  'param_uszkodzony__cat',
#  'feature_system-start-stop__cat',
#  'feature_światła-xenonowe__cat',
#  'feature_bluetooth__cat',
#  'param_kraj-pochodzenia__cat',
#  'feature_czujnik-martwego-pola__cat',
# ...

# %%
xgb_params = {
        "max_depth":10,
        'n_estimators':100,
        "learning_rate":0.1,
        "seed":0,
        "tree_method":"gpu_hist"
    }

run_model(xgb.XGBRegressor(**xgb_params), important_features_xgb)
# Out:
# Depth 11 :  7144.0 	 42.0 	 7186.0

# %%
df["param_rok-produkcji"].unique()
# Out:
# array(['2018', '2011', '2015', '2009', '2017', '2012', '2013', '2007',
#        '2001', '2016', '2006', '2008', '2004', '1999', '2000', '2010',
#        '2005', '2002', '1998', '2014', '2003', '1982', '1995', '1997',
#        '1992', '1993', '1994', '1996', '1989', '1988', '1967', '1987',
#        '1970', '1959', '1990', '1991', '1974', -1, '1975', '1973', '1953',
#        '1985', '1984', '1986', '1981', '1979', '1960', '1983', '1978',
#        '1964', '1980', '1972', '1969', '1956', '1966', '1977', '1962',
#        '1965', '1971', '1963', '1961', '1952', '1949', '1976', '1937',
#        '1968', '1958', '1955', '1933', '1929', '1957', '1944', '1954',
#        '1932', '1936', '1947', '1948'], dtype=object)

# %%
df["param_rok-produkcji"] = df["param_rok-produkcji"].map(lambda x: -1 if str(x)=="None" else x).astype(int)

# %%
df["param_rok-produkcji"].unique()
# Out:
# array([2018, 2011, 2015, 2009, 2017, 2012, 2013, 2007, 2001, 2016, 2006,
#        2008, 2004, 1999, 2000, 2010, 2005, 2002, 1998, 2014, 2003, 1982,
#        1995, 1997, 1992, 1993, 1994, 1996, 1989, 1988, 1967, 1987, 1970,
#        1959, 1990, 1991, 1974,   -1, 1975, 1973, 1953, 1985, 1984, 1986,
#        1981, 1979, 1960, 1983, 1978, 1964, 1980, 1972, 1969, 1956, 1966,
#        1977, 1962, 1965, 1971, 1963, 1961, 1952, 1949, 1976, 1937, 1968,
#        1958, 1955, 1933, 1929, 1957, 1944, 1954, 1932, 1936, 1947, 1948])

# %%
# ### podmieniamy rok na prawdziwa liczbe

# important_features_xgb = ['param_rok-produkcji',
#  'param_stan__cat',
#  'param_napęd__cat',
#  'param_skrzynia-biegów__cat',
#  'param_marka-pojazdu__cat',
#  'param_moc__cat',
#  'param_faktura-vat__cat',
#  'param_pojemność-skokowa__cat',
#  'feature_kamera-cofania__cat',
#  'param_typ__cat',
#  'param_wersja__cat',
#  'param_model-pojazdu__cat',
#  'param_kod-silnika__cat',
#  'feature_łopatki-zmiany-biegów__cat',
#  'seller_type__cat',
#  'feature_czujniki-parkowania-przednie__cat',
#  'feature_asystent-pasa-ruchu__cat',
#  'seller_name__cat',
#  'feature_wspomaganie-kierownicy__cat',
#  'param_rodzaj-paliwa__cat',
#  'seller_address__cat',
#  'feature_regulowane-zawieszenie__cat',
#  'created_at__cat',
#  'param_przebieg__cat',
#  'param_liczba-miejsc__cat',
#  'feature_światła-led__cat',
#  'param_uszkodzony__cat',
#  'feature_system-start-stop__cat',
#  'feature_światła-xenonowe__cat',
#  'feature_bluetooth__cat']

# xgb_params = {
#         "max_depth":10,
#         'n_estimators':100,
#         "learning_rate":0.1,
#         "seed":0,
#         "tree_method":"gpu_hist"
#     }

# run_model(xgb.XGBRegressor(**xgb_params), important_features_xgb)

# %%
def run_model(model, feats):
    X = df[feats].values
    y = df["price_value"].values
    model = model
    scores = -cross_val_score(model, X, y, cv=3, scoring="neg_mean_absolute_error", n_jobs=-1)
    print(f"n {n} lr {lr} max_depth {max_d}: \t score: {round(np.mean(scores))}\t std: {round(np.std(scores))}\t score+std: {round(np.mean(scores) + np.std(scores))}")

# %%
n=200
for lr in (0.05, 0.1):
    for max_d in (10,11):

        xgb_params = {
                "max_depth":max_d,
                'n_estimators':n,
                "learning_rate":lr,
                "seed":0,
                "tree_method":"gpu_hist"
                }
        run_model(xgb.XGBRegressor(**xgb_params), important_features_xgb)
# Out:
# n 200 lr 0.05 max_depth 10: 	 score: 7086.0	 std: 56.0	 score+std: 7142.0
# n 200 lr 0.05 max_depth 11: 	 score: 7022.0	 std: 44.0	 score+std: 7066.0
# n 200 lr 0.1 max_depth 10: 	 score: 6902.0	 std: 45.0	 score+std: 6947.0
# n 200 lr 0.1 max_depth 11: 	 score: 6912.0	 std: 42.0	 score+std: 6954.0
